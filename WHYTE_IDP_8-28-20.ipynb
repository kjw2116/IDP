# %% [markdown]
# # **MY IDP in PYTHON!**

# %% [markdown]
# ## *I am an obesity researcher who studies determinants of energy expenditure, energy intake and body composition in the United States.  My previous research focused on innovative energy expenditure methodology and most recently, ultra-processed food in maternal dietary intake and its impact on neonatal body composition.   My short-term objective is to expand my skills in intervention design and analyses and to develop expertise in body composition assessments. My long-term goal is to hold a tenure-track faculty position at a leading research institution so that I can independently conduct interdisciplinary, methodologically advanced and translational research with the goal of refining body composition and energy expenditure methodology and improving the health and livelihood of families and individuals with obesity.*

# %%
# %pwd

# %%
import pandas as pd

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tabulate import tabulate

# %%
help(tabulate)

# %%
table=[["June 2019-August 2019", "Completed literature review and additional analyses on infant body composition for manuscript", "Abstract submitted to TOS and NYCORF", "Propane Validations and WRIC organization", "Responsiblity in Conduction Research, R and Excel Statistics Workshop"],["Sept 2019 - Dec 2019", "Completed introduction through methods on dissertation manuscript and Lift 1-yr manuscript","Presented poster at NYCORF, CUIMC Postdoc Symposium and Obesity Society as oral", "Completed data collection and analyses for human validation studies in WRIC and circadian alightment study","BIST 8157 Longitudinal Data Analysis, Nature Scientific Writing, Nature Peer Review Course, Trans NORC Workshop, Dewitt Goodman, Naomi Berrie Diabetes, Appetitive"],["Jan 2020-March 2020", "Completed manuscripts for high level editing", "Began participation in grant application process with UG3", "n/a", "G4010 RCR course, M9870 Grant writing course, Dewitt Goodman, Naomie Berrie Diabetes, Research Computing Bootcamp, Python and Unix coding workshops", "2 Manuscripts reviewed"]["April 2020-June 2020", "Completed LIFT manuscript and sent to co-authors, Dissertation manuscript with additional analyses", "Partcipated in submission of grant application", "Restarted leak assessment testing with main chamber". "R for Basic Scientists", "NIH Strides, Google ML Courses 1 and 2, ASN Annual Meeting", "Reviewed 3 Manuscripts"], ["July 2020-Sept 2020", "Submitted LIFT manuscript to Pediatric Obesity, Dissertation manuscript out to coauthors", "Leaks in main chamber identified and plan to seal disseminated", "Research Computing Bootcamp, Google ML Course 3", "Reviewed 2 manuscripts"]]

# %%
whyte_idp=pd.read_csv('Whyte_IDP_8.28.2020_V1.csv')

# %%
whyte_idp.describe()
# Out:
#                             MON-YEAR       ACTIVITY TYPE  \
# count                             84                  84
# unique                             5                  10
# top     September 2019-December 2019  Seminars/Workshops
# freq                              22                  24
#
#                       ACTIVITIES START DATE DATE COMPLETED  \
# count                         85         85             84
# unique                        71         70             53
# top     Dissertation Manuscript      Weekly        ongoing
# freq                           4          4             14
#
#                         NOTES
# count                      46
# unique                     37
# top     Offered by FRC office
# freq                        3

# %%
print(whyte_idp)

# %%
whyte_idp.describe()

# %%
pd.set_option('display.max_columns', 6) #replace n with the number of columns you want to see completely
pd.set_option('display.max_rows', 86) #replace n with the number of rows you want to see completely

# %%
df=whyte_idp

# %%
whyte_idp ##just hit run on this cell, the other cells are code for me to practice a workflow
# Out:
#                         MON-YEAR            ACTIVITY TYPE  \
# 0         June 2019- August 2019        Directed Readings
# 1         June 2019- August 2019        Directed Readings
# 2         June 2019- August 2019        Laboratory Skills
# 3         June 2019- August 2019        Laboratory Skills
# 4         June 2019- August 2019        Laboratory Skills
# 5         June 2019- August 2019       Scientific Writing
# 6         June 2019- August 2019       Scientific Writing
# 7                            NaN       Scientific Writing
# 8         June 2019- August 2019       Scientific Writing
# 9         June 2019- August 2019                 Workshop
# 10        June 2019- August 2019                 Workshop
# 11        June 2019- August 2019                  Service
# 12        June 2019- August 2019                Mentoring
# 13  September 2019-December 2019        Directed Readings
# 14  September 2019-December 2019        Directed Readings
# ...
